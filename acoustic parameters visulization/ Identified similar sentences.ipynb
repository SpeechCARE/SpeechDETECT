# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=False)
# Out:
# Mounted at /content/gdrive

# %%
from collections import defaultdict

def tokenize(text):
    # Simple word tokenization
    return text.split()

def find_common_subsequences(doc1,doc2,min_length=3):
    # Tokenize both documents
    words1 = tokenize(doc1)
    words2 = tokenize(doc2)

    # Function to get all subsequences of length 'min_length' or greater
    def get_subsequences(words,min_length):
        subsequences = defaultdict(int)
        # for length in range(min_length,len(words) + 1):
        for length in [min_length]:
            for i in range(len(words) - length + 1):
                subsequence = tuple(words[i:i + length])
                subsequences[subsequence] += 1
        return subsequences

    # Get all subsequences for both documents
    subsequences1 = get_subsequences(words1,min_length)
    subsequences2 = get_subsequences(words2,min_length)

    # Find the common subsequences
    common_subsequences = set(subsequences1.keys()) & set(subsequences2.keys())

    return common_subsequences

# %%
import openpyxl

ADs = []
CNs = []

wb = openpyxl.load_workbook("/content/gdrive/MyDrive/DePiC.xlsx")
ws = wb.active
rows = list(ws.iter_rows(values_only=True))

for row in rows[1:]:
    if row[2] == 1:
        ADs.append({"id": row[0],"text": row[1]})
    elif row[2] == 0:
        CNs.append({"id": row[0],"text": row[1]})
    else:
      print("NOT FOUND")

# %%
min_length = 5

res = []

for i in range(len(ADs)):
    for j in range(len(CNs)):
        common_subs = find_common_subsequences(ADs[i]["text"],CNs[j]["text"],min_length=min_length)
        for sub in common_subs:
            print(ADs[i]["id"],CNs[j]["id"],' '.join(sub))
            res.append({
                "AD_ID": ADs[i]["id"],
                "CN_ID": CNs[j]["id"],
                "sentence": ' '.join(sub)
            })
# Out:
# adrso025 adrso016 cookies from the cookie jar
# adrso025 adrso016 from the cookie jar and
# adrso025 adrso157 cookies from the cookie jar
# adrso025 adrso157 from the cookie jar and
# adrso025 adrso169 cookies from the cookie jar
# adrso024 adrso276 is off the cookie jar.
# adrso024 adrso276 lid is off the cookie
# adrso045 adrso170 don't know what's going on.
# adrso045 adrso291 don't know what that is.
# adrso045 adrso291 I don't know what that
# adrso035 adrso315 is reaching for a cookie
# adrso032 adrso002 the cookie jar on the
# adrso032 adrso017 water on the floor and
# adrso032 adrso156 and he's about to fall
# adrso053 adrso182 I think I mentioned that
# adrso053 adrso182 think I mentioned that the
# adrso072 adrso151 taking cookies out the cookie
# adrso072 adrso164 taking cookies out of the
# adrso072 adrso164 cookies out of the cookie
# adrso072 adrso165 of the cookie jar, the
# adrso072 adrso165 taking cookies out of the
# adrso072 adrso165 out of the cookie jar,
# adrso072 adrso165 cookies out of the cookie
# adrso072 adrso270 taking cookies out of the
# adrso072 adrso309 out of the cookie jar,
# adrso072 adrso309 cookies out of the cookie
# adrso074 adrso276 two cups and a plate
# adrso074 adrso265 and a plate on the
# adrso074 adrso281 a plate in her hand
# adrso068 adrso023 the mother's washing dishes and
# adrso068 adrso183 he's falling off the stool.
# adrso059 adrso015 boys trying to get cookies
# adrso059 adrso015 little boys trying to get
# adrso059 adrso308 little boys trying to get
# adrso071 adrso015 the sink is running over
# adrso071 adrso158 in the cookie jar and
# adrso071 adrso161 telling him to be quiet
# adrso071 adrso177 going on outside the window.
# adrso071 adrso276 telling him to be quiet
# adrso071 adrso276 is telling him to be
# adrso071 adrso291 the sink is running over
# adrso106 adrso003 on the top of the
# adrso106 adrso005 that's coming out of the
# adrso106 adrso005 coming out of the sink.
# adrso106 adrso274 out of the cookie jar
# adrso106 adrso268 the sink and over the
# adrso110 adrso164 and she's standing in the
# adrso110 adrso164 and the water is running
# adrso110 adrso186 and the water is running
# adrso110 adrso270 and the water is running
# adrso110 adrso308 and she's standing in the
# adrso110 adrso299 and she's standing in the
# adrso110 adrso310 she's standing in the water,
# adrso110 adrso312 and she's standing in the
# adrso089 adrso008 the cookies and the little
# adrso089 adrso262 and the little girl is
# adrso089 adrso276 and the little girl is
# adrso123 adrso160 is reaching for a cookie.
# adrso123 adrso158 in the cookie jar and
# adrso123 adrso172 girl is reaching for a
# adrso123 adrso183 girl is reaching for a
# adrso123 adrso183 is reaching for a cookie.
# adrso123 adrso315 girl is reaching for a
# adrso141 adrso023 the mother's washing dishes and
# adrso144 adrso158 in the cookie jar and
# adrso144 adrso261 I don't know what the
# adrso189 adrso164 the water is running over
# adrso189 adrso164 and the water is running
# adrso189 adrso164 the sink and the water
# adrso189 adrso164 sink and the water is
# adrso189 adrso164 water is running over and
# adrso189 adrso156 boys in the cookie jar
# adrso189 adrso158 the cookie jar and he's
# adrso189 adrso158 in the cookie jar and
# adrso189 adrso259 all over the floor and
# adrso189 adrso186 and the water is running
# adrso189 adrso276 at the sink and the
# adrso189 adrso268 all over the floor and
# adrso189 adrso270 and the water is running
# adrso189 adrso308 the water is running over
# adrso189 adrso309 all over the floor and
# adrso128 adrso164 and the water is running
# adrso128 adrso186 the water is running out
# adrso128 adrso186 and the water is running
# adrso128 adrso270 and the water is running
# adrso128 adrso300 water is running out of
# adrso138 adrso148 boy is trying to get
# adrso138 adrso148 the boy is trying to
# adrso138 adrso259 washing the dishes and the
# adrso138 adrso273 about all I can see
# adrso200 adrso148 out of the cookie jar.
# adrso200 adrso012 out of the cookie jar.
# adrso200 adrso164 cookies out of the cookie
# adrso200 adrso164 out of the cookie jar.
# adrso200 adrso165 cookies out of the cookie
# adrso200 adrso276 because the window is open.
# adrso200 adrso309 cookies out of the cookie
# adrso200 adrso310 out of the cookie jar.
# adrso200 adrso315 the boy is getting the
# adrso190 adrso002 is reaching up for a
# adrso190 adrso019 is drying the dishes and
# adrso190 adrso019 mom is drying the dishes
# adrso190 adrso276 there are two cups and
# adrso190 adrso274 reaching up for a cookie
# adrso190 adrso274 is reaching up for a
# adrso188 adrso165 Mother's drying the dishes. I
# adrso188 adrso276 is working at the sink
# adrso188 adrso296 I don't see anything else.
# adrso218 adrso148 trying to get a cookie
# adrso222 adrso169 I don't know what else
# adrso222 adrso169 don't know what else you
# adrso209 adrso012 on a stool and the
# adrso209 adrso172 stool and the stool is
# adrso209 adrso172 on a stool and the
# adrso209 adrso172 a stool and the stool
# adrso209 adrso296 I don't see anything else
# adrso209 adrso302 is getting ready to fall
# adrso212 adrso008 out of the sink and
# adrso205 adrso161 little boy is up on
# adrso202 adrso002 reaching up for a cookie.
# adrso202 adrso151 taking cookies out the cookie
# adrso202 adrso259 dishes and the sink is
# adrso229 adrso261 I don't know what the
# adrso229 adrso310 gonna fall off the stool.
# adrso233 adrso148 out of the cookie jar.
# adrso233 adrso012 out of the cookie jar.
# adrso233 adrso164 cookies out of the cookie
# adrso233 adrso164 out of the cookie jar.
# adrso233 adrso165 cookies out of the cookie
# adrso233 adrso264 cookie jar. Little girls reaching
# adrso233 adrso264 jar. Little girls reaching up
# adrso233 adrso309 cookies out of the cookie
# adrso233 adrso310 out of the cookie jar.
# adrso247 adrso160 running over on the floor.
# adrso247 adrso302 letting the water run over
# adrso247 adrso302 the water run over the
# adrso247 adrso302 she's letting the water run
# adrso245 adrso281 a cookie jar on the
# adrso232 adrso021 water running over the sink.
# adrso224 adrso012 up on a stool and
# adrso224 adrso012 on a stool and the
# adrso224 adrso172 on a stool and the
# adrso224 adrso274 he has one in his
# adrso244 adrso019 looks like he's gonna fall
# adrso228 adrso157 the cookie jar and the
# adrso228 adrso186 the cookie jar and the
# adrso248 adrso159 the water is spilling over
# adrso234 adrso007 a stool that's about to
# adrso234 adrso007 on a stool that's about
# adrso234 adrso002 a stool that's about to
# adrso234 adrso002 on a stool that's about
# adrso234 adrso308 trying to get into the
# adrso234 adrso308 to get into the cookie
# adrso249 adrso160 water's running over on the
# adrso249 adrso160 running over on the floor.
# adrso249 adrso160 the water's running over on
# adrso249 adrso164 cookies out of the cookie
# adrso249 adrso165 out of the cookie jar,
# adrso249 adrso165 cookies out of the cookie
# adrso249 adrso309 out of the cookie jar,
# adrso249 adrso309 cookies out of the cookie
# adrso246 adrso156 boys in the cookie jar
# adrso246 adrso158 in the cookie jar and
# adrso246 adrso157 the cookie jar and the
# adrso246 adrso186 the cookie jar and the
# adrso246 adrso296 a plate in her hand.
# adrso250 adrso148 you see going on in
# adrso253 adrso180 cookies out of the jar
# adrso253 adrso308 trying to get some cookies
# adrso253 adrso308 boys trying to get some

# %%
def find_consecutive_times(df,sentence):
    words = sentence.split()  # Split the sentence into words
    sequence_length = len(words)
    sequence_start_index = None

    # Iterate over the dataframe rows
    for i,row in df.iterrows():
        # If the row's content matches the first word of the sequence and we are not already in a sequence
        if row['content'] == words[0] and sequence_start_index is None:
            sequence_start_index = i  # Set the potential start of the sequence

        # If we are in a sequence,check if the current row's content matches the expected word in the sentence
        elif sequence_start_index is not None:
            expected_word_index = i - sequence_start_index
            if expected_word_index < sequence_length and row['content'] == words[expected_word_index]:
                if expected_word_index == sequence_length - 1:
                    # We found the whole sequence,return the start time of the first word and the end time of the last word
                    start_time_of_sentence = df.iloc[sequence_start_index]['start_time']
                    end_time_of_sentence = row['end_time']
                    return start_time_of_sentence,end_time_of_sentence
            else:
                # Reset the sequence if the word does not match
                sequence_start_index = None

    return None,None

# Let's leave the sentence empty again for you to provide it
sentence = ""

# Uncomment the following line and replace the sentence with the one you'd like to find times for
# start_time,end_time = find_consecutive_times(data,sentence)

# Please provide the sentence you want to search for,and I will execute the function.

# %%
import pandas as pd
import csv

AD_PATH = "/content/gdrive/MyDrive/AD_patients_excel_files"
CN_PATH = "/content/gdrive/MyDrive/CN_patients_excel_files"

with open("output.csv", "w") as fout:
    fieldnames = ['sentence', 'uid', 'label', 'start_time', 'end_time']
    writer = csv.DictWriter(fout, fieldnames=fieldnames)

    for row in res:
        print(f"{row['AD_ID'], row['CN_ID'], row['sentence']}")
        ad_user_path = f"{AD_PATH}/{row['AD_ID']}.wav.xlsx"
        dfs = pd.read_excel(ad_user_path)

        start_time,end_time = find_consecutive_times(dfs,row["sentence"])
        writer.writerow({
            "sentence": row['sentence'],
            "uid": row['AD_ID'],
            "label": 1,
            "start_time": start_time,
            "end_time": end_time
        })
        cn_user_path = f"{CN_PATH}/{row['CN_ID']}.wav.xlsx"
        dfs = pd.read_excel(cn_user_path)

        start_time,end_time = find_consecutive_times(dfs,row["sentence"])
        writer.writerow({
            "sentence": row['sentence'],
            "uid": row['CN_ID'],
            "label": 0,
            "start_time": start_time,
            "end_time": end_time
        })
# Out:
# ('adrso025', 'adrso016', 'cookies from the cookie jar')
# ('adrso025', 'adrso016', 'from the cookie jar and')
# ('adrso025', 'adrso157', 'cookies from the cookie jar')
# ('adrso025', 'adrso157', 'from the cookie jar and')
# ('adrso025', 'adrso169', 'cookies from the cookie jar')
# ('adrso024', 'adrso276', 'is off the cookie jar.')
# ('adrso024', 'adrso276', 'lid is off the cookie')
# ('adrso045', 'adrso170', "don't know what's going on.")
# ('adrso045', 'adrso291', "don't know what that is.")
# ('adrso045', 'adrso291', "I don't know what that")
# ('adrso035', 'adrso315', 'is reaching for a cookie')
# ('adrso032', 'adrso002', 'the cookie jar on the')
# ('adrso032', 'adrso017', 'water on the floor and')
# ('adrso032', 'adrso156', "and he's about to fall")
# ('adrso053', 'adrso182', 'I think I mentioned that')
# ('adrso053', 'adrso182', 'think I mentioned that the')
# ('adrso072', 'adrso151', 'taking cookies out the cookie')
# ('adrso072', 'adrso164', 'taking cookies out of the')
# ('adrso072', 'adrso164', 'cookies out of the cookie')
# ('adrso072', 'adrso165', 'of the cookie jar, the')
# ('adrso072', 'adrso165', 'taking cookies out of the')
# ('adrso072', 'adrso165', 'out of the cookie jar,')
# ('adrso072', 'adrso165', 'cookies out of the cookie')
# ('adrso072', 'adrso270', 'taking cookies out of the')
# ('adrso072', 'adrso309', 'out of the cookie jar,')
# ('adrso072', 'adrso309', 'cookies out of the cookie')
# ('adrso074', 'adrso276', 'two cups and a plate')
# ('adrso074', 'adrso265', 'and a plate on the')
# ('adrso074', 'adrso281', 'a plate in her hand')
# ('adrso068', 'adrso023', "the mother's washing dishes and")
# ('adrso068', 'adrso183', "he's falling off the stool.")
# ('adrso059', 'adrso015', 'boys trying to get cookies')
# ('adrso059', 'adrso015', 'little boys trying to get')
# ('adrso059', 'adrso308', 'little boys trying to get')
# ('adrso071', 'adrso015', 'the sink is running over')
# ('adrso071', 'adrso158', 'in the cookie jar and')
# ('adrso071', 'adrso161', 'telling him to be quiet')
# ('adrso071', 'adrso177', 'going on outside the window.')
# ('adrso071', 'adrso276', 'telling him to be quiet')
# ('adrso071', 'adrso276', 'is telling him to be')
# ('adrso071', 'adrso291', 'the sink is running over')
# ('adrso106', 'adrso003', 'on the top of the')
# ('adrso106', 'adrso005', "that's coming out of the")
# ('adrso106', 'adrso005', 'coming out of the sink.')
# ('adrso106', 'adrso274', 'out of the cookie jar')
# ('adrso106', 'adrso268', 'the sink and over the')
# ('adrso110', 'adrso164', "and she's standing in the")
# ('adrso110', 'adrso164', 'and the water is running')
# ('adrso110', 'adrso186', 'and the water is running')
# ('adrso110', 'adrso270', 'and the water is running')
# ('adrso110', 'adrso308', "and she's standing in the")
# ('adrso110', 'adrso299', "and she's standing in the")
# ('adrso110', 'adrso310', "she's standing in the water,")
# ('adrso110', 'adrso312', "and she's standing in the")
# ('adrso089', 'adrso008', 'the cookies and the little')
# ('adrso089', 'adrso262', 'and the little girl is')
# ('adrso089', 'adrso276', 'and the little girl is')
# ('adrso123', 'adrso160', 'is reaching for a cookie.')
# ('adrso123', 'adrso158', 'in the cookie jar and')
# ('adrso123', 'adrso172', 'girl is reaching for a')
# ('adrso123', 'adrso183', 'girl is reaching for a')
# ('adrso123', 'adrso183', 'is reaching for a cookie.')
# ('adrso123', 'adrso315', 'girl is reaching for a')
# ('adrso141', 'adrso023', "the mother's washing dishes and")
# ('adrso144', 'adrso158', 'in the cookie jar and')
# ('adrso144', 'adrso261', "I don't know what the")
# ('adrso189', 'adrso164', 'the water is running over')
# ('adrso189', 'adrso164', 'and the water is running')
# ('adrso189', 'adrso164', 'the sink and the water')
# ('adrso189', 'adrso164', 'sink and the water is')
# ('adrso189', 'adrso164', 'water is running over and')
# ('adrso189', 'adrso156', 'boys in the cookie jar')
# ('adrso189', 'adrso158', "the cookie jar and he's")
# ('adrso189', 'adrso158', 'in the cookie jar and')
# ('adrso189', 'adrso259', 'all over the floor and')
# ('adrso189', 'adrso186', 'and the water is running')
# ('adrso189', 'adrso276', 'at the sink and the')
# ('adrso189', 'adrso268', 'all over the floor and')
# ('adrso189', 'adrso270', 'and the water is running')
# ('adrso189', 'adrso308', 'the water is running over')
# ('adrso189', 'adrso309', 'all over the floor and')
# ('adrso128', 'adrso164', 'and the water is running')
# ('adrso128', 'adrso186', 'the water is running out')
# ('adrso128', 'adrso186', 'and the water is running')
# ('adrso128', 'adrso270', 'and the water is running')
# ('adrso128', 'adrso300', 'water is running out of')
# ('adrso138', 'adrso148', 'boy is trying to get')
# ('adrso138', 'adrso148', 'the boy is trying to')
# ('adrso138', 'adrso259', 'washing the dishes and the')
# ('adrso138', 'adrso273', 'about all I can see')
# ('adrso200', 'adrso148', 'out of the cookie jar.')
# ('adrso200', 'adrso012', 'out of the cookie jar.')
# ('adrso200', 'adrso164', 'cookies out of the cookie')
# ('adrso200', 'adrso164', 'out of the cookie jar.')
# ('adrso200', 'adrso165', 'cookies out of the cookie')
# ('adrso200', 'adrso276', 'because the window is open.')
# ('adrso200', 'adrso309', 'cookies out of the cookie')
# ('adrso200', 'adrso310', 'out of the cookie jar.')
# ('adrso200', 'adrso315', 'the boy is getting the')
# ('adrso190', 'adrso002', 'is reaching up for a')
# ('adrso190', 'adrso019', 'is drying the dishes and')
# ('adrso190', 'adrso019', 'mom is drying the dishes')
# ('adrso190', 'adrso276', 'there are two cups and')
# ('adrso190', 'adrso274', 'reaching up for a cookie')
# ('adrso190', 'adrso274', 'is reaching up for a')
# ('adrso188', 'adrso165', "Mother's drying the dishes. I")
# ('adrso188', 'adrso276', 'is working at the sink')
# ('adrso188', 'adrso296', "I don't see anything else.")
# ('adrso218', 'adrso148', 'trying to get a cookie')
# ('adrso222', 'adrso169', "I don't know what else")
# ('adrso222', 'adrso169', "don't know what else you")
# ('adrso209', 'adrso012', 'on a stool and the')
# ('adrso209', 'adrso172', 'stool and the stool is')
# ('adrso209', 'adrso172', 'on a stool and the')
# ('adrso209', 'adrso172', 'a stool and the stool')
# ('adrso209', 'adrso296', "I don't see anything else")
# ('adrso209', 'adrso302', 'is getting ready to fall')
# ('adrso212', 'adrso008', 'out of the sink and')
# ('adrso205', 'adrso161', 'little boy is up on')
# ('adrso202', 'adrso002', 'reaching up for a cookie.')
# ('adrso202', 'adrso151', 'taking cookies out the cookie')
# ('adrso202', 'adrso259', 'dishes and the sink is')
# ('adrso229', 'adrso261', "I don't know what the")
# ('adrso229', 'adrso310', 'gonna fall off the stool.')
# ('adrso233', 'adrso148', 'out of the cookie jar.')
# ('adrso233', 'adrso012', 'out of the cookie jar.')
# ('adrso233', 'adrso164', 'cookies out of the cookie')
# ('adrso233', 'adrso164', 'out of the cookie jar.')
# ('adrso233', 'adrso165', 'cookies out of the cookie')
# ('adrso233', 'adrso264', 'cookie jar. Little girls reaching')
# ('adrso233', 'adrso264', 'jar. Little girls reaching up')
# ('adrso233', 'adrso309', 'cookies out of the cookie')
# ('adrso233', 'adrso310', 'out of the cookie jar.')
# ('adrso247', 'adrso160', 'running over on the floor.')
# ('adrso247', 'adrso302', 'letting the water run over')
# ('adrso247', 'adrso302', 'the water run over the')
# ('adrso247', 'adrso302', "she's letting the water run")
# ('adrso245', 'adrso281', 'a cookie jar on the')
# ('adrso232', 'adrso021', 'water running over the sink.')
# ('adrso224', 'adrso012', 'up on a stool and')
# ('adrso224', 'adrso012', 'on a stool and the')
# ('adrso224', 'adrso172', 'on a stool and the')
# ('adrso224', 'adrso274', 'he has one in his')
# ('adrso244', 'adrso019', "looks like he's gonna fall")
# ('adrso228', 'adrso157', 'the cookie jar and the')
# ('adrso228', 'adrso186', 'the cookie jar and the')
# ('adrso248', 'adrso159', 'the water is spilling over')
# ('adrso234', 'adrso007', "a stool that's about to")
# ('adrso234', 'adrso007', "on a stool that's about")
# ('adrso234', 'adrso002', "a stool that's about to")
# ('adrso234', 'adrso002', "on a stool that's about")
# ('adrso234', 'adrso308', 'trying to get into the')
# ('adrso234', 'adrso308', 'to get into the cookie')
# ('adrso249', 'adrso160', "water's running over on the")
# ('adrso249', 'adrso160', 'running over on the floor.')
# ('adrso249', 'adrso160', "the water's running over on")
# ('adrso249', 'adrso164', 'cookies out of the cookie')
# ('adrso249', 'adrso165', 'out of the cookie jar,')
# ('adrso249', 'adrso165', 'cookies out of the cookie')
# ('adrso249', 'adrso309', 'out of the cookie jar,')
# ('adrso249', 'adrso309', 'cookies out of the cookie')
# ('adrso246', 'adrso156', 'boys in the cookie jar')
# ('adrso246', 'adrso158', 'in the cookie jar and')
# ('adrso246', 'adrso157', 'the cookie jar and the')
# ('adrso246', 'adrso186', 'the cookie jar and the')
# ('adrso246', 'adrso296', 'a plate in her hand.')
# ('adrso250', 'adrso148', 'you see going on in')
# ('adrso253', 'adrso180', 'cookies out of the jar')
# ('adrso253', 'adrso308', 'trying to get some cookies')
# ('adrso253', 'adrso308', 'boys trying to get some')
